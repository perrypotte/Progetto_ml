# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from YAML
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolov8n.yaml").load("yolov8n.pt")  # build from YAML and transfer weights

# Train the model
# results = model.train(data="coco8.yaml", epochs=100, imgsz=640)

#results = model.train(data="euro_dataset/data.yaml", epochs=100, imgsz=640) #lo yaml lo cerca qui ma poi le immagini le cerca in un path autistico
# Out:
# Transferred 355/355 items from pretrained weights

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.pt")  # pretrained YOLOv8n model

# Run batched inference on a list of images
results = model(["im1.jpg"])  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
    result.save(filename="result.jpg")  # save to disk
# Out:
# 0: 640x640 1 vase, 213.5ms
# Speed: 7.0ms preprocess, 213.5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# ## Guarda una directory e printa i risultati

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO("yolov8n.pt")

# Define path to directory containing images and videos for inference
source = "datasets/euro_dataset/train/images"

# Run inference on the source
results = model(source, stream=True)  # generator of Results objects

# %%
# View results
i=0

for r in results:
    # print(r.boxes)  # print the Boxes object containing the detection bounding boxes
    # r.save_crop("./results", file_name=('im.jpg'))  #salva senza bounding box
    r.save("result.jpg")
    i=i+1
# Out:
# image 1/666 c:\Users\Andrea Perricone\Desktop\ml\purogetto\datasets\euro_dataset\train\images\00334d13-4962-4b53-9dd2-121f8f000beb_jpg.rf.10daa7dfba7e7482ca79720cd27ec8f4.jpg: 640x640 1 clock, 232.3ms
# image 2/666 c:\Users\Andrea Perricone\Desktop\ml\purogetto\datasets\euro_dataset\train\images\016bad69c2_jpg.rf.30581d3b4cf3e212d66a9de8f643efed.jpg: 640x640 (no detections), 229.2ms
# image 3/666 c:\Users\Andrea Perricone\Desktop\ml\purogetto\datasets\euro_dataset\train\images\01c410de-6fd3-4612-8bb1-5a179c351a20_jpg.rf.bce5e4495f7724dc371bb9d4722a174b.jpg: 640x640 (no detections), 212.1ms
# image 4/666 c:\Users\Andrea Perricone\Desktop\ml\purogetto\datasets\euro_dataset\train\images\01c410de-6fd3-4612-8bb1-5a179c351a20_jpg.rf.c45498975de07dac0e332275df3efa2d.jpg: 640x640 1 cell phone, 214.4ms
# image 5/666 c:\Users\Andrea Perricone\Desktop\ml\purogetto\datasets\euro_dataset\train\images\01cf2502d5_jpg.rf.30235f08634dd31660c593606f3436b3.jpg: 640x640 1 cup, 1 clock, 1 vase, 214.5ms
# ...
